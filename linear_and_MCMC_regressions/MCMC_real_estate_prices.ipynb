# %% [markdown]
# # Baysian and Frequentists Linear Models

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import scipy
import pymc3 as pm

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('kc_house_data.csv')

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
X,y = data['price'], data[['date', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train.to_csv('data/train_x.csv')
X_test.to_csv('data/test_x.csv')
y_train.to_csv('data/train_y.csv')
y_test.to_csv('data/test_y.csv')

# %%
f.set_figheight(15)
f.set_figwidth(20)

# %%
k = 0 
cols = y_train.columns
for i in range(4):
    for j in range(5):
        if k == 19:
            ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=0.5, ha='center')
        if k < 19:
            ax[i, j].plot(X_train, y_train[cols[k]], 'bo');
        k += 1

f
